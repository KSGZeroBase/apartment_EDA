# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "A" : ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    "B" : ['one', 'two', 'one', 'three', 'three', 'two', 'one', 'three', 'two', 'two', ],
    "C" : np.random.randn(10),
    "D" : np.random.randn(10),
})

df
# Out:
#    A      B         C         D
# 0  A    one  0.213017  0.700451
# 1  B    two  0.902395 -0.083694
# 2  A    one  1.288234  0.985284
# 3  B  three  0.285026  0.687456
# 4  A  three  0.908457 -0.905452
# 5  B    two  0.658849  0.711100
# 6  A    one  0.993444  0.067832
# 7  B  three  1.018129  0.407822
# 8  A    two  0.181335 -0.299199
# 9  B    two -0.595484  1.065725

# %%
df.groupby('A').mean()
# Out:
# C:\Users\rluvu\AppData\Local\Temp\ipykernel_6436\714605139.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('A').mean()
#           C         D
# A
# A  0.716898  0.109783
# B  0.453783  0.557682

# %%
df.groupby(['A', 'B']).mean()
# Out:
#                 C         D
# A B
# A one    0.831565  0.584522
#   three  0.908457 -0.905452
#   two    0.181335 -0.299199
# B three  0.651578  0.547639
#   two    0.321920  0.564377

# %%
df.groupby('A').agg({'C':np.sum, "D": np.mean})
# Out:
#           C         D
# A
# A  3.584488  0.109783
# B  2.268915  0.557682

# %%
df.groupby('A').agg(
    max_C = pd.NamedAgg(column="C", aggfunc='max'),
    min_D = pd.NamedAgg(column="D", aggfunc='min'),
    mean_C = pd.NamedAgg(column="C", aggfunc='mean'),
)
# Out:
#       max_C     min_D    mean_C
# A
# A  1.288234 -0.905452  0.716898
# B  1.018129 -0.083694  0.453783

# %%
df.groupby('B').filter(lambda x: len(x)<4)
# Out:
#    A      B         C         D
# 0  A    one  0.213017  0.700451
# 2  A    one  1.288234  0.985284
# 3  B  three  0.285026  0.687456
# 4  A  three  0.908457 -0.905452
# 6  A    one  0.993444  0.067832
# 7  B  three  1.018129  0.407822

# %%
df
# Out:
#    A      B         C         D
# 0  A    one  0.213017  0.700451
# 1  B    two  0.902395 -0.083694
# 2  A    one  1.288234  0.985284
# 3  B  three  0.285026  0.687456
# 4  A  three  0.908457 -0.905452
# 5  B    two  0.658849  0.711100
# 6  A    one  0.993444  0.067832
# 7  B  three  1.018129  0.407822
# 8  A    two  0.181335 -0.299199
# 9  B    two -0.595484  1.065725

# %%
df.groupby('A')['D'].transform('mean')
# Out:
# 0    0.109783
# 1    0.557682
# 2    0.109783
# 3    0.557682
# 4    0.109783
# 5    0.557682
# 6    0.109783
# 7    0.557682
# 8    0.109783
# 9    0.557682
# Name: D, dtype: float64

# %%
def normalize(x):
    return (x-x.mean())/x.std()

df.groupby('A')['C'].apply(normalize)
# Out:
# C:\Users\rluvu\AppData\Local\Temp\ipykernel_6436\3032865742.py:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df.groupby('A')['C'].apply(normalize)
# 0   -1.017825
# 1    0.689921
# 2    1.154085
# 3   -0.259531
# 4    0.386946
# 5    0.315371
# 6    0.558617
# 7    0.867908
# 8   -1.081823
# 9   -1.613669
# Name: C, dtype: float64

# %%
df
# Out:
#    A      B         C         D
# 0  A    one  0.213017  0.700451
# 1  B    two  0.902395 -0.083694
# 2  A    one  1.288234  0.985284
# 3  B  three  0.285026  0.687456
# 4  A  three  0.908457 -0.905452
# 5  B    two  0.658849  0.711100
# 6  A    one  0.993444  0.067832
# 7  B  three  1.018129  0.407822
# 8  A    two  0.181335 -0.299199
# 9  B    two -0.595484  1.065725

# %%
df.groupby('A')['C'].rank()
# Out:
# 0    2.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    3.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    1.0
# 9    1.0
# Name: C, dtype: float64

# %%
df.groupby('A').agg(lambda x: x.max()-x.min())
# Out:
# C:\Users\rluvu\AppData\Local\Temp\ipykernel_6436\248048230.py:1: FutureWarning: ['B'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('A').agg(lambda x: x.max()-x.min())
#           C         D
# A
# A  1.106899  1.890736
# B  1.613614  1.149419

# %%
df.groupby("A").describe()
# Out:
#       C                                                                        \
#   count      mean       std       min       25%       50%       75%       max
# A
# A   5.0  0.716898  0.495056  0.181335  0.213017  0.908457  0.993444  1.288234
# B   5.0  0.453783  0.650237 -0.595484  0.285026  0.658849  0.902395  1.018129
#
#       D
#   count      mean       std       min       25%       50%       75%       max
# A
# A   5.0  0.109783  0.760776 -0.905452 -0.299199  0.067832  0.700451  0.985284
# B   5.0  0.557682  0.427875 -0.083694  0.407822  0.687456  0.711100  1.065725
